# %%
import pandas as pd

# %%
data=pd.read_csv('Placement.csv')

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.shape
# Out:
# (215, 15)

# %%
#Univariate analysis
import seaborn as sns

# %%
sns.distplot(data['mba_p'],kde=True,kde_kws={'color':'red'},color='blue')
# Out:
# C:\Users\Arun\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
#Bivariate analyiss
#pair plot

sns.pairplot(data,diag_kind='kde',kind='scatter',hue='gender',palette = "husl")

# %%
sns.jointplot(data,x='mba_p',y='salary',kind='kde')

# %%
sns.jointplot(data,x='mba_p',y='salary',kind='hex')

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M  67.00   Others  91.00  Others  Commerce     58.00  Sci&Tech
# 1      2      M  79.33  Central  78.33  Others   Science     77.48  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
#Categorical plot
sns.stripplot(data=data,x='specialisation',y='mba_p')

# %%
sns.stripplot(data=data,x='specialisation',y='mba_p',jitter=True)

# %%
#swarm plot
sns.swarmplot(data=data,x='specialisation',y='mba_p')

# %%
# Facet grid

import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Gender': ['Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Extracurricular': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
    'Exam_Score': [85, 70, 90, 75, 80, 65, 88, 72]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a facet grid
g = sns.FacetGrid(df, col='Gender', row='Extracurricular')
# Map the exam scores to the grid
g.map(plt.hist, 'Exam_Score')

# Add titles to each subplot
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')


plt.show()

# %%
# Distribution observation
sns.violinplot(data,x='specialisation',y='mba_p',hue='gender',loc=0,bbox_to_anchor=(1, 0.5))

# %%
sns.boxplot(data,x='specialisation',y='mba_p',hue='gender')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
sns.barplot(data=data,x='specialisation',y='salary',hue='gender')

# %%
sns.countplot(data=data,x='specialisation',hue='gender')

# %%
sns.pointplot(data=data,x='ssc_p',y='hsc_b',hue='gender')
plt.show()

# %%
df_exercise=sns.load_dataset('exercise')
df_exercise.head(2)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest

# %%
sns.catplot(data=df_exercise,x='time',y='pulse',col='diet',hue='kind',kind='violin')

# %%
df_tips=sns.load_dataset('tips')

# %%
df_tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.lmplot(data=df_tips,x='total_bill',y='tip')

# %%
sns.regplot(data=df_tips,x='total_bill',y='tip')

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df = sns.load_dataset('anscombe')
sns.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
from matplotlib import pyplot as plt
g=sns.FacetGrid(df_tips,col='time')
g.map(plt.hist,'tip')
plt.show()

# %%
df_iris = sns.load_dataset('iris')
g = sns.PairGrid(df_iris)
g.map(plt.scatter);
plt.show()
